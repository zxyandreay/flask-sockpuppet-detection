# %%
import sklearn
print(sklearn.__version__)

# %%
import joblib
model = joblib.load('sockpuppet_model.pkl')
print(dir(model))  # This will print all attributes and methods of the loaded model object
